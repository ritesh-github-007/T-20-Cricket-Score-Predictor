# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filenames = []
for file in os.listdir('/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/data/data'):
  filenames.append(os.path.join('/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/data/data',file))

# %%
filenames[0:5]
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/data/data/1031665.yaml',
#  '/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/data/data/1031435.yaml',
#  '/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/data/data/1031433.yaml',
#  '/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/data/data/1031431.yaml',
#  '/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/data/data/1020029.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
  with open(file,'r') as f:
    df = pd.json_normalize(safe_load(f))
    df['match_id']  = counter
    final_df = final_df.append(df)
    counter+=1

final_df
# Out:
# 100%|██████████| 1438/1438 [12:57<00:00,  1.85it/s]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'England', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 0   [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 0   [{'1st innings': {'team': 'South Africa', 'del...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
#
# ...

# %%
backup = final_df.copy()

# %%
final_df.head(2)
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0  [{'1st innings': {'team': 'England', 'deliveri...                0.9
#
#   meta.created  meta.revision          info.city    info.dates info.gender  \
# 0   2020-08-08              1  Chester-le-Street  [2017-09-16]        male
# 0   2017-06-26              1            Cardiff  [2017-06-25]        male
#
#   info.match_type  info.match_type_number info.outcome.winner  ...  match_id  \
# 0             T20                   622.0         West Indies  ...         1
# 0             T20                     NaN             England  ...         2
#
#    info.outcome.by.wickets info.outcome.method info.neutral_venue  \
# 0                      NaN                 NaN                NaN
# 0                      NaN                 NaN                NaN
#
#   info.outcome.result info.outcome.eliminator info.bowl_out  \
# ...

# %%
final_df.drop(columns=[
                       'meta.data_version',
                       'meta.created',
                       'meta.revision',
                       'info.outcome.bowl_out',
                       'info.bowl_out',
                       'info.supersubs.South Africa',
                       'info.supersubs.New Zealand',
                       'info.outcome.eliminator',
                       'info.outcome.result',
                       'info.outcome.method',
                       'info.neutral_venue',
                       'info.match_type_number',
                       'info.outcome.by.runs',
                       'info.outcome.by.wickets' 
],inplace = True)

# %%
final_df.shape
# Out:
# (1438, 14)

# %%
final_df['info.gender'].value_counts()
# Out:
# male      972
# female    466
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender']=='male']
final_df.drop(columns=['info.gender'],inplace = True)
final_df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                               innings          info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  Chester-le-Street
# 0   [{'1st innings': {'team': 'England', 'deliveri...            Cardiff
# 0   [{'1st innings': {'team': 'South Africa', 'del...            Taunton
# 0   [{'1st innings': {'team': 'South Africa', 'del...        Southampton
# 0   [{'1st innings': {'team': 'South Africa', 'del...           Auckland
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...                NaN
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...          Hong Kong
# ...

# %%
final_df = final_df[final_df['info.overs']==20]
final_df.drop(columns=['info.overs','info.match_type'],inplace = True)
final_df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                               innings          info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  Chester-le-Street
# 0   [{'1st innings': {'team': 'England', 'deliveri...            Cardiff
# 0   [{'1st innings': {'team': 'South Africa', 'del...            Taunton
# 0   [{'1st innings': {'team': 'South Africa', 'del...        Southampton
# 0   [{'1st innings': {'team': 'South Africa', 'del...           Auckland
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...                NaN
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...          Hong Kong
# ...

# %%
import pickle
pickle.dump(final_df,open('/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/dataset_level1.pkl','rb'))
matches
# Out:
#                                               innings          info.city  \
# 0   [{'1st innings': {'team': 'West Indies', 'deli...  Chester-le-Street
# 0   [{'1st innings': {'team': 'England', 'deliveri...            Cardiff
# 0   [{'1st innings': {'team': 'South Africa', 'del...            Taunton
# 0   [{'1st innings': {'team': 'South Africa', 'del...        Southampton
# 0   [{'1st innings': {'team': 'South Africa', 'del...           Auckland
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...                NaN
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...          Hong Kong
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...                NaN
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...          Hong Kong
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...         Townsville
#
#       info.dates info.outcome.winner info.player_of_match  \
# ...

# %%
matches.iloc[0]['innings']
# Out:
# [{'1st innings': {'deliveries': [{0.1: {'batsman': 'CH Gayle',
#       'bowler': 'DJ Willey',
#       'non_striker': 'E Lewis',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {0.2: {'batsman': 'CH Gayle',
#       'bowler': 'DJ Willey',
#       'non_striker': 'E Lewis',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.3: {'batsman': 'CH Gayle',
#       'bowler': 'DJ Willey',
#       'non_striker': 'E Lewis',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {0.4: {'batsman': 'E Lewis',
#       'bowler': 'DJ Willey',
#       'extras': {'wides': 1},
#       'non_striker': 'CH Gayle',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {0.5: {'batsman': 'E Lewis',
#       'bowler': 'DJ Willey',
#       'non_striker': 'CH Gayle',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.6: {'batsman': 'E Lewis',
#       'bowler': 'DJ Willey',
#       'non_striker': 'CH Gayle',
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
delivery_df
# Out:
#     match_id                        teams batting_team  ball      batsman  \
# 0          2       [West Indies, England]  West Indies   0.1     CH Gayle
# 1          2       [West Indies, England]  West Indies   0.2     CH Gayle
# 2          2       [West Indies, England]  West Indies   0.3     CH Gayle
# 3          2       [West Indies, England]  West Indies   0.4      E Lewis
# 4          2       [West Indies, England]  West Indies   0.5      E Lewis
# ..       ...                          ...          ...   ...          ...
# 62       970  [Ireland, Papua New Guinea]      Ireland  10.2  MC Sorensen
# 63       970  [Ireland, Papua New Guinea]      Ireland  10.3  MC Sorensen
# 64       970  [Ireland, Papua New Guinea]      Ireland  10.4   AD Poynter
# 65       970  [Ireland, Papua New Guinea]      Ireland  10.5  MC Sorensen
# 66       970  [Ireland, Papua New Guinea]      Ireland  10.6   AD Poynter
#
#        bowler  runs player_dismissed               city                 venue
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#     match_id                        teams batting_team  ball      batsman  \
# 0          2       [West Indies, England]  West Indies   0.1     CH Gayle
# 1          2       [West Indies, England]  West Indies   0.2     CH Gayle
# 2          2       [West Indies, England]  West Indies   0.3     CH Gayle
# 3          2       [West Indies, England]  West Indies   0.4      E Lewis
# 4          2       [West Indies, England]  West Indies   0.5      E Lewis
# ..       ...                          ...          ...   ...          ...
# 62       970  [Ireland, Papua New Guinea]      Ireland  10.2  MC Sorensen
# 63       970  [Ireland, Papua New Guinea]      Ireland  10.3  MC Sorensen
# 64       970  [Ireland, Papua New Guinea]      Ireland  10.4   AD Poynter
# 65       970  [Ireland, Papua New Guinea]      Ireland  10.5  MC Sorensen
# 66       970  [Ireland, Papua New Guinea]      Ireland  10.6   AD Poynter
#
#        bowler  runs player_dismissed               city                 venue  \
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#     match_id batting_team  ball      batsman     bowler  runs  \
# 0          2  West Indies   0.1     CH Gayle  DJ Willey     4
# 1          2  West Indies   0.2     CH Gayle  DJ Willey     0
# 2          2  West Indies   0.3     CH Gayle  DJ Willey     1
# 3          2  West Indies   0.4      E Lewis  DJ Willey     1
# 4          2  West Indies   0.5      E Lewis  DJ Willey     0
# ..       ...          ...   ...          ...        ...   ...
# 62       970      Ireland  10.2  MC Sorensen    N Vanua     2
# 63       970      Ireland  10.3  MC Sorensen    N Vanua     1
# 64       970      Ireland  10.4   AD Poynter    N Vanua     1
# 65       970      Ireland  10.5  MC Sorensen    N Vanua     1
# 66       970      Ireland  10.6   AD Poynter    N Vanua     1
#
#    player_dismissed               city                 venue      bowling_team
# 0                 0  Chester-le-Street      Riverside Ground           England
# ...

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball   batsman        bowler  runs  \
# 0           2  West Indies   0.1  CH Gayle     DJ Willey     4
# 1           2  West Indies   0.2  CH Gayle     DJ Willey     0
# 2           2  West Indies   0.3  CH Gayle     DJ Willey     1
# 3           2  West Indies   0.4   E Lewis     DJ Willey     1
# 4           2  West Indies   0.5   E Lewis     DJ Willey     0
# ..        ...          ...   ...       ...           ...   ...
# 116       960        India  18.1  R Ashwin  PVD Chameera     1
# 117       960        India  18.2   A Nehra  PVD Chameera     0
# 118       960        India  18.3   A Nehra  PVD Chameera     2
# 119       960        India  18.4   A Nehra  PVD Chameera     0
# 120       960        India  18.5  R Ashwin  PVD Chameera     1
#
#     player_dismissed               city  \
# 0                  0  Chester-le-Street
# 1                  0  Chester-le-Street
# 2                  0  Chester-le-Street
# 3                  0  Chester-le-Street
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies      England   0.1     4                0
# 1           2  West Indies      England   0.2     0                0
# 2           2  West Indies      England   0.3     1                0
# 3           2  West Indies      England   0.4     1                0
# 4           2  West Indies      England   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 116       960        India    Sri Lanka  18.1     1                0
# 117       960        India    Sri Lanka  18.2     0                0
# 118       960        India    Sri Lanka  18.3     2                0
# 119       960        India    Sri Lanka  18.4     0          A Nehra
# 120       960        India    Sri Lanka  18.5     1        JJ Bumrah
#
#                   city                                    venue
# 0    Chester-le-Street                         Riverside Ground
# ...

# %%
pickle.dump(output,open('/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/dataset_level2.pkl','wb'))

# %%
df = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/dataset_level2.pkl','rb'))
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies      England   0.1     4                0
# 1           2  West Indies      England   0.2     0                0
# 2           2  West Indies      England   0.3     1                0
# 3           2  West Indies      England   0.4     1                0
# 4           2  West Indies      England   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 116       960        India    Sri Lanka  18.1     1                0
# 117       960        India    Sri Lanka  18.2     0                0
# 118       960        India    Sri Lanka  18.3     2                0
# 119       960        India    Sri Lanka  18.4     0          A Nehra
# 120       960        India    Sri Lanka  18.5     1        JJ Bumrah
#
#                   city                                    venue
# 0    Chester-le-Street                         Riverside Ground
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8303
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2846
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       627
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies      England   0.1     4                0
# 1           2  West Indies      England   0.2     0                0
# 2           2  West Indies      England   0.3     1                0
# 3           2  West Indies      England   0.4     1                0
# 4           2  West Indies      England   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 116       960        India    Sri Lanka  18.1     1                0
# 117       960        India    Sri Lanka  18.2     0                0
# 118       960        India    Sri Lanka  18.3     2                0
# 119       960        India    Sri Lanka  18.4     0          A Nehra
# 120       960        India    Sri Lanka  18.5     1        JJ Bumrah
#
#                   city
# 0    Chester-le-Street
# 1    Chester-le-Street
# 2    Chester-le-Street
# 3    Chester-le-Street
# ...

# %%
df['city'].value_counts()
# Out:
# Colombo          4208
# Mirpur           3420
# Johannesburg     3331
# Auckland         2903
# Dubai            2846
#                  ...
# Dharamsala        122
# Chennai           122
# Potchefstroom     122
# Ahmedabad         121
# Carrara            64
# Name: city, Length: 87, dtype: int64

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team  bowling_team  ball  runs player_dismissed     city
# 0           3      England  South Africa   0.1     0                0  Cardiff
# 1           3      England  South Africa   0.2     0                0  Cardiff
# 2           3      England  South Africa   0.3     2                0  Cardiff
# 3           3      England  South Africa   0.4     0                0  Cardiff
# 4           3      England  South Africa   0.5     0                0  Cardiff
# ..        ...          ...           ...   ...   ...              ...      ...
# 118       949        India    Bangladesh  19.2     0        RG Sharma   Mirpur
# 119       949        India    Bangladesh  19.3     0                0   Mirpur
# 120       949        India    Bangladesh  19.4     0        HH Pandya   Mirpur
# 121       949        India    Bangladesh  19.5     2                0   Mirpur
# 122       949        India    Bangladesh  19.6     6                0   Mirpur
#
# ...

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      match_id batting_team  bowling_team  ball  runs player_dismissed  \
# 0           3      England  South Africa   0.1     0                0
# 1           3      England  South Africa   0.2     0                0
# 2           3      England  South Africa   0.3     2                0
# 3           3      England  South Africa   0.4     0                0
# 4           3      England  South Africa   0.5     0                0
# ..        ...          ...           ...   ...   ...              ...
# 118       949        India    Bangladesh  19.2     0        RG Sharma
# 119       949        India    Bangladesh  19.3     0                0
# 120       949        India    Bangladesh  19.4     0        HH Pandya
# 121       949        India    Bangladesh  19.5     2                0
# 122       949        India    Bangladesh  19.6     6                0
#
#         city  current_score
# 0    Cardiff              0
# 1    Cardiff              0
# 2    Cardiff              2
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      match_id batting_team  bowling_team  ball  runs player_dismissed  \
# 0           3      England  South Africa   0.1     0                0
# 1           3      England  South Africa   0.2     0                0
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      match_id batting_team  bowling_team  ball  runs player_dismissed  \
# 0           3      England  South Africa   0.1     0                0
# 1           3      England  South Africa   0.2     0                0
# 2           3      England  South Africa   0.3     2                0
# 3           3      England  South Africa   0.4     0                0
# 4           3      England  South Africa   0.5     0                0
# ..        ...          ...           ...   ...   ...              ...
# 118       949        India    Bangladesh  19.2     0        RG Sharma
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      match_id batting_team  bowling_team  ball  runs player_dismissed  \
# 0           3      England  South Africa   0.1     0                0
# 1           3      England  South Africa   0.2     0                0
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#      match_id batting_team  bowling_team  ball  runs  player_dismissed  \
# 0           3      England  South Africa   0.1     0                 0
# 1           3      England  South Africa   0.2     0                 0
# 2           3      England  South Africa   0.3     2                 0
# 3           3      England  South Africa   0.4     0                 0
# 4           3      England  South Africa   0.5     0                 0
# ..        ...          ...           ...   ...   ...               ...
# 118       949        India    Bangladesh  19.2     0                 5
# 119       949        India    Bangladesh  19.3     0                 5
# 120       949        India    Bangladesh  19.4     0                 6
# 121       949        India    Bangladesh  19.5     2                 6
# 122       949        India    Bangladesh  19.6     6                 6
#
#         city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      match_id batting_team  bowling_team  ball  runs  player_dismissed  \
# 0           3      England  South Africa   0.1     0                 0
# 1           3      England  South Africa   0.2     0                 0
# 2           3      England  South Africa   0.3     2                 0
# 3           3      England  South Africa   0.4     0                 0
# 4           3      England  South Africa   0.5     0                 0
# ..        ...          ...           ...   ...   ...               ...
# 118       949        India    Bangladesh  19.2     0                 5
# 119       949        India    Bangladesh  19.3     0                 5
# 120       949        India    Bangladesh  19.4     0                 6
# 121       949        India    Bangladesh  19.5     2                 6
# 122       949        India    Bangladesh  19.6     6                 6
#
#         city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      match_id batting_team  bowling_team  ball  runs  player_dismissed  \
# 0           3      England  South Africa   0.1     0                 0
# 1           3      England  South Africa   0.2     0                 0
# 2           3      England  South Africa   0.3     2                 0
# 3           3      England  South Africa   0.4     0                 0
# 4           3      England  South Africa   0.5     0                 0
# ..        ...          ...           ...   ...   ...               ...
# 118       949        India    Bangladesh  19.2     0                 5
# 119       949        India    Bangladesh  19.3     0                 5
# 120       949        India    Bangladesh  19.4     0                 6
# 121       949        India    Bangladesh  19.5     2                 6
# 122       949        India    Bangladesh  19.6     6                 6
#
#         city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df
# Out:
#       batting_team  bowling_team     city  current_score  balls_left  \
# 29         England  South Africa  Cardiff             38          90
# 30         England  South Africa  Cardiff             39          89
# 31         England  South Africa  Cardiff             40          89
# 32         England  South Africa  Cardiff             41          88
# 33         England  South Africa  Cardiff             41          87
# ...            ...           ...      ...            ...         ...
# 51104        India    Bangladesh   Mirpur            158           4
# 51105        India    Bangladesh   Mirpur            158           3
# 51106        India    Bangladesh   Mirpur            158           2
# 51107        India    Bangladesh   Mirpur            160           1
# 51108        India    Bangladesh   Mirpur            166           0
#
#        wickets_left       crr  last_five  runs_x
# 29                9  7.600000       38.0     181
# ...

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 34954     Sri Lanka      Pakistan       Colombo             94          35
# 49579       England   West Indies        Mumbai            116          32
# 49589       England   West Indies        Mumbai            135          22
# 3868       Pakistan   West Indies      Trinidad            130           9
# 23067       England  South Africa      Barbados            100          46
# ...             ...           ...           ...            ...         ...
# 10249     Australia  South Africa  Johannesburg             86          68
# 42679  South Africa      Pakistan  Johannesburg            109          28
# 6816   South Africa      Pakistan  Johannesburg            101          36
# 15971   West Indies    Bangladesh  Johannesburg             59          69
# 43316  South Africa         India        Mirpur            152           9
#
#        wickets_left       crr  last_five
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# [08:03:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9878710570209268
# 1.6278398711680142

# %%
pickle.dump(pipe,open('/content/drive/MyDrive/Colab Notebooks/ML Projects/T-20 Cricket Score Predictor/pipe.pkl','wb'))
